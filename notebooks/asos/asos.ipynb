# %% [markdown]
# Download Instructions:
#
# Download the asos_digital_experiments_dataset.csv from https://osf.io/64jsb/ and put the file in data/

# %%
import numpy as np
import os
import torch 
import pandas as pd

os.chdir("../..")

from aexgym.model import TreatmentLinearModel, TreatmentPersonalModel
from aexgym.agent import LinearTS, DeconfoundedTS, LinearUniform
from aexgym.objectives import ContextualBestArm, ContextualSimpleRegret, ConstraintBestArm
from scripts.setup_script import make_uniform_prior
from notebooks.asos.make_asos_env import make_matrices, ASOS

# %%
asos_path = 'data/asos_digital_experiments_dataset.csv'
# Load the ASOS dataset
asos_df = pd.read_csv(asos_path)

# %%
#parameters 
n_days = 10
n_arms = 10
context_len = n_days 
n_steps = n_days 
batch_size = 100 
metric_id_list = [2]
n_objs = len(metric_id_list)
exp_id = '036afc' 


env = ASOS(
    asos_df = asos_df, 
    context_len = n_days, 
    batch_size = batch_size, 
    n_steps = n_steps, 
    n_arms = n_arms, 
    seed = 0, 
    exp_id = exp_id, 
    metric_id_list = metric_id_list, 
    subtract=True, 
    demean=False
)

#print means of asos env 
env.reset()
print(env.mean_matrix[:,:,0])
# Out:
# tensor([[0.0319, 0.0313, 0.0308, 0.0316, 0.0313, 0.0305, 0.0307, 0.0325, 0.0313,
#          0.0320],
#         [0.0156, 0.0160, 0.0163, 0.0158, 0.0160, 0.0164, 0.0163, 0.0153, 0.0160,
#          0.0156],
#         [0.0282, 0.0271, 0.0264, 0.0278, 0.0272, 0.0259, 0.0262, 0.0292, 0.0272,
#          0.0283],
#         [0.0160, 0.0150, 0.0142, 0.0156, 0.0150, 0.0137, 0.0141, 0.0171, 0.0151,
#          0.0162],
#         [0.0212, 0.0217, 0.0221, 0.0214, 0.0217, 0.0224, 0.0222, 0.0206, 0.0217,
#          0.0211],
#         [0.0071, 0.0065, 0.0060, 0.0069, 0.0065, 0.0057, 0.0060, 0.0077, 0.0065,
#          0.0072],
#         [0.0133, 0.0125, 0.0118, 0.0129, 0.0125, 0.0114, 0.0117, 0.0141, 0.0125,
#          0.0134],
#         [0.0044, 0.0046, 0.0047, 0.0045, 0.0046, 0.0048, 0.0047, 0.0042, 0.0046,
#          0.0044],
#         [0.0139, 0.0138, 0.0138, 0.0138, 0.0138, 0.0138, 0.0138, 0.0139, 0.0138,
#          0.0139],
#         [0.0165, 0.0165, 0.0164, 0.0165, 0.0165, 0.0164, 0.0164, 0.0165, 0.0165,
#          0.0165]])

# %%
#make agent models 
s2 = torch.mean(env.var_matrix, dim=1)
scaling = 1 / batch_size 
beta, sigma = make_uniform_prior(context_len + n_arms, scaling, n_objs)
beta_mix, sigma_mix = make_uniform_prior(context_len + n_arms + context_len*n_arms, scaling, n_objs)
model = TreatmentLinearModel(
    beta_0 = beta, 
    sigma_0 = sigma, 
    n_arms = n_arms, 
    s2 = s2,
    n_objs = n_objs
)

mix_model = TreatmentPersonalModel(
    beta_0 = beta_mix, 
    sigma_0 = sigma_mix, 
    n_arms = n_arms, 
    s2 = s2, 
    n_objs = n_objs
)

# %%
#agent = LinearUniform(model, "Linear Uniform", n_samples = 10000)
#agent = DeconfoundedTS(mix_model, "Linear TS", toptwo=False, n_samples = 1)
agent = LinearTS(model, "Linear TS", toptwo=False, n_samples = 1)

# %%
device = "cpu"
print_probs = False
objective = ContextualBestArm()
torch.set_printoptions(sci_mode=False)
regret_list = []
percent_arms_correct_list = []

for i in range(10000):
    env.reset()
    #print(env.mean_matrix)
    all_contexts, cur_step = env.reset()
    beta, sigma = agent.model.reset()
    #print(beta, sigma)
    beta, sigma = beta.to(device), sigma.to(device)
    beta_0, sigma_0 = beta.clone(), sigma.clone()
    
    while env.n_steps - cur_step > 0:

        #move to device 
        state_contexts, action_contexts, eval_contexts = tuple(contexts.to(device) for contexts in all_contexts)
        
        #get batch size 
        batch_size = state_contexts.shape[0]
        #train agent 
        agent.train_agent(
            beta = beta, 
            sigma = sigma, 
            cur_step = cur_step, 
            n_steps = env.n_steps, 
            train_context_sampler = env.sample_train_contexts, 
            eval_contexts = eval_contexts, 
            real_batch_size = batch_size, 
            objective=objective)
        
        #get probabilities
        probs = agent(
            beta = beta, 
            sigma = sigma, 
            contexts = state_contexts, 
            action_contexts = action_contexts, 
            objective = objective
        )
     
        #print probabilities 
        if print_probs == True:
            print(agent.name, env.n_steps - cur_step, torch.mean(probs, dim=0))
        
        #get actions and move to new state
        actions = torch.distributions.Categorical(probs).sample()
        
        #move to next environment state 
        all_contexts, sampled_rewards, sampled_features, cur_step  = env.step(
            state_contexts = state_contexts, 
            action_contexts = action_contexts, 
            actions = actions
        )
        
        #update model state 
        beta, sigma = agent.model.update_posterior(
            beta = beta_0, 
            sigma = sigma_0, 
            rewards = sampled_rewards, 
            features = agent.model.feature_map(actions, state_contexts, action_contexts), 
            idx = cur_step-1
        )

    #get evaluation contexts and true rewards 
    eval_contexts = env.sample_eval_contexts(access=True).to(device)
    true_eval_rewards = env.get_true_rewards(eval_contexts, action_contexts)
    
    #calculate results from objective 
    results_dict = objective(
        fantasy_rewards = agent.fantasize(beta, eval_contexts, action_contexts).to(device), 
        true_rewards = true_eval_rewards.to(device)
    )
    
    #append results 
    percent_arms_correct_list.append(results_dict['percent_arms_correct'])
    regret_list.append(results_dict['regret'])

    #print results 
    if i % 10 == 0:
        
        print("Iteration: ", i)
        print("Regret: ", np.mean(regret_list))
        print("Percent Arms Correct: ", np.mean(percent_arms_correct_list))
# Out:
# Regret:  0.0007327217608690262
# Percent Arms Correct:  0.0
# Regret:  0.0005307866429740733
# Percent Arms Correct:  0.09090909090909091
# Regret:  0.0004806674662090483
# Percent Arms Correct:  0.09523809523809523
# Regret:  0.00046716233895670984
# Percent Arms Correct:  0.0967741935483871
# Regret:  0.0004859129194079376
# Percent Arms Correct:  0.07317073170731707
# Regret:  0.000460727724666689
# Percent Arms Correct:  0.0784313725490196
# Regret:  0.00043927472023690334
# Percent Arms Correct:  0.09836065573770492
# Regret:  0.00043112837092977173
# Percent Arms Correct:  0.08450704225352113
# Regret:  0.00043841681362670145
# Percent Arms Correct:  0.07407407407407407
# Percent Arms Correct:  0.052689352360043906
# Regret:  0.00045594909146476646
# Percent Arms Correct:  0.053203040173724216
# Regret:  0.0004561576676163842
# Percent Arms Correct:  0.05370569280343716
# Regret:  0.0004555647252533312
# Percent Arms Correct:  0.05419766206163656
# Regret:  0.00045681761266305244
# Percent Arms Correct:  0.05362776025236593
# Regret:  0.00045738767340205587
# Percent Arms Correct:  0.054110301768990635
# Regret:  0.00045692774895904727
# Percent Arms Correct:  0.053553038105046344
# Regret:  0.00045734866845984466
# Percent Arms Correct:  0.053007135575942915
# Regret:  0.0004574881582760546
# Percent Arms Correct:  0.05247225025227043
# Regret:  0.0004569373235895441
# Percent Arms Correct:  0.053946053946053944
# Regret:  0.0004556891218225751
# Percent Arms Correct:  0.05341246290801187
# Regret:  0.00045577598503999684
# Percent Arms Correct:  0.05288932419196866
# Regret:  0.00045573867127573917
# Percent Arms Correct:  0.052376333656644035
# Regret:  0.0004543040438012133
# Percent Arms Correct:  0.052833813640730067
# Regret:  0.00045483638235606203
# Percent Arms Correct:  0.05233111322549953
# Regret:  0.00045434393438104184
# Percent Arms Correct:  0.051837888784165884
# Regret:  0.0004542452430163
# Percent Arms Correct:  0.05228758169934641
# Regret:  0.0004545988103204254
# Percent Arms Correct:  0.05180388529139685
# Regret:  0.00045399416979030117
# Percent Arms Correct:  0.05224564619615032
# Regret:  0.0004533294310876178
# Percent Arms Correct:  0.05449591280653951
# Regret:  0.0004541222777294748
# Percent Arms Correct:  0.054005400540054004
# Regret:  0.0004541324958351443
# Percent Arms Correct:  0.05530776092774309
# Regret:  0.00045349197602187713
# Percent Arms Correct:  0.05570291777188329
# Regret:  0.0004535247355464464
# Percent Arms Correct:  0.05521472392638037
# Regret:  0.0004538014469640758
# Percent Arms Correct:  0.05473501303214596
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       6 percent_arms_correct_list = []
#      10 for i in range(10000):
# ---> 11     env.reset()
#      12     #print(env.mean_matrix)
#      13     all_contexts, cur_step = env.reset()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/columbia/projects/aexgym/notebooks/asos/make_asos_env.py:181, in ASOS.reset(self)
#     180 def reset(self):
# --> 181     self.mean_matrix, self.var_matrix = make_matrices(self.asos_df, self.context_len, self.n_arms, self.zs[self.z_counter], exp_id = self.exp_id, metric_id_list = self.metric_id_list, demean=self.demean, subtract = self.subtract)
#     182     #print(self.mean_matrix)
#     183     if self.s2 is not None:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/columbia/projects/aexgym/notebooks/asos/make_asos_env.py:31, in make_matrices(asos_df, T, num_arms, arms, exp_id, metric_id_list, demean, subtract)
#      29             scale = row['mean_t'] - row['mean_c']
#      30             arm_dat[t][k]['mean'] = row['mean_c'] + scale * arms[i][k]
# ---> 31             arm_dat[t][k]['var']  = row['variance_t']
#      33 if demean:
#      34     for t in range(T):
#
# File ~/miniconda3/envs/aexgym/lib/python3.11/site-packages/pandas/core/series.py:945, in Series.__getitem__(self, key)
#     942     out._name = self._name
#     943     return out.__finalize__(self)
# --> 945 def __getitem__(self, key):
#     946     check_dict_or_set_indexers(key)
#     947     key = com.apply_if_callable(key, self)
#
# KeyboardInterrupt:
